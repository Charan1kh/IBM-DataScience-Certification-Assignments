# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Data Science Tools and Ecosystem

# %% [markdown]
# ![image.png](attachment:575c2a08-e87b-45b6-b9a9-2a3d6ae8be6f.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![image.png](attachment:a20d8949-de75-4dad-ae83-06c61c3b71da.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1. Python

# %% [markdown]
# 2. R

# %% [markdown]
# 3. Java

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# ![image.png](attachment:ce04459a-fe35-4e4b-be42-5d89a5c701b2.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. GGplot
# 3. matplotlib

# %% [markdown]
# ![image.png](attachment:38ab0448-71e3-4776-ae72-530e497f88f2.png)

# %% [markdown]
# Data Science Tools:
# 1. Jupyter Notebook
# 2. R studio
# 3. IBM Watson

# %% [markdown]
# ![image.png](attachment:a7885827-58a2-4bed-8c99-5a1d9b23aacb.png)

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python

# %%
4 + 6
# Out:
# 10

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers

# %%
# This will convert 200 minutes to hours by dividing by 60.
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# |![image.png](attachment:0ab151f8-6c26-431d-937c-794a3fd558d0.png)

# %% [markdown]
# # List popular languages for Data Science

# %% [markdown]
# **Objectives:**
#
# - Understand the basics of Python programming.
# - Learn how to manipulate data using Python libraries.
# - Explore data visualization techniques with popular libraries.
# - Gain familiarity with version control using Git and GitHub.
# - Identify popular languages for Data Science.

# %% [markdown]
# ![image.png](attachment:05805fc4-0f3c-4285-a565-2558301a65c0.png)

# %% [markdown]
# # Author:
# charan K

# %% [markdown]
# ![image.png](attachment:114ba9c2-fa75-4151-838d-d2c6b384868e.png)
